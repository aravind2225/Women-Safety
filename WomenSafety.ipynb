# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind2225/Women-Safety/blob/main/WomenSafety.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
data = pd.read_csv("/content/Crime_Data_from_2020_to_Present (1).csv")
data
# Out:
#            DR_NO  AREA    AREA NAME  Rpt Dist No  \
# 0      200606074     6    Hollywood          646
# 1      201212036    12  77th Street         1268
# 2      200914052     9     Van Nuys          935
# 3      200810920     8      West LA          841
# 4      201210786    12  77th Street         1259
# ...          ...   ...          ...          ...
# 98461  241509057    15  N Hollywood         1526
# 98462  241304905    13       Newton         1367
# 98463  241305457    13       Newton         1347
# 98464  242004546    20      Olympic         2013
# 98465  240309674     3    Southwest          358
#
#                                           Crm Cd Desc  Vict Age Vict Sex  \
# 0                                             PIMPING        23        F
# 1      ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        28        F
# 2                            BATTERY - SIMPLE ASSAULT        57        F
# 3                            BATTERY - SIMPLE ASSAULT        78        F
# ...

# %%
columns_to_cluster = ['Vict Age', 'LAT', 'LON']
data_cluster = data[columns_to_cluster].dropna()


scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_cluster)


kmeans = KMeans(n_clusters=500, init='k-means++', random_state=42)
data_cluster['Cluster'] = kmeans.fit_predict(scaled_data)


cluster_counts = data_cluster['Cluster'].value_counts()


very_low_threshold = cluster_counts.quantile(0.05)
low_threshold = cluster_counts.quantile(0.25)
high_threshold = cluster_counts.quantile(0.75)

def categorize_risk(count):
    if count <= very_low_threshold:
        return "Safe"
    elif count <= low_threshold:
        return "Low Risk"
    elif count <= high_threshold:
        return "Moderate Risk"
    else:
        return "High Risk"


cluster_counts = cluster_counts.to_frame(name='Count')
cluster_counts['Risk'] = cluster_counts['Count'].apply(categorize_risk)

data_cluster['Risk'] = data_cluster['Cluster'].map(cluster_counts['Risk'])


# data_cluster.to_csv("clustered_data_with_risk_labels.csv", index=False)
data_cluster
# Out:
#        Vict Age      LAT       LON  Cluster           Risk
# 0            23  34.1016 -118.3370      219      High Risk
# 1            28  33.9654 -118.2739      334      High Risk
# 2            57  34.1847 -118.4400      235  Moderate Risk
# 3            78  34.0423 -118.4656      164  Moderate Risk
# 4            26  33.9730 -118.2652      153      High Risk
# ...         ...      ...       ...      ...            ...
# 98461        54  34.1868 -118.3878       63  Moderate Risk
# 98462        41  33.9993 -118.2432      233      High Risk
# 98463        52  34.0098 -118.2413      200      High Risk
# 98464        80  34.0690 -118.3054      222  Moderate Risk
# 98465        70  34.0215 -118.2868      170  Moderate Risk
#
# [98466 rows x 5 columns]

# %%
scaled_in=scaler.transform(np.array([[41,	33.9993,	-118.2432]]))
val = kmeans.predict(scaled_in)[0]
val
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 233

# %%
data_cluster[data_cluster['Cluster']==val]['Risk'].values[0]
# Out:
# 'High Risk'

# %%
# import pandas as pd
# import json


# filtered_df = data_cluster[data_cluster["Risk"] == "High Risk"]
# filtered_low = data_cluster[data_cluster["Risk"] == "Low Risk"]
# filtered_mod = data_cluster[data_cluster["Risk"] == "Moderate Risk"]
# filtered_safe = data_cluster[data_cluster["Risk"] == "Safe"]

# result = {"High Risk": filtered_df["Cluster"].tolist(),

#           "Low Risk": filtered_low["Cluster"].tolist(),

#           "Moderate Risk": filtered_mod["Cluster"].tolist(),

#           "Safe": filtered_safe["Cluster"].tolist()



#           }


# result_json = json.dumps(result, indent=4)

# with open("cluster.json", 'w') as json_file:
#     json.dump(result, json_file, indent=4)

# %%
# import pickle

# objects_to_save_minimal = {
#     "scaler": scaler,
#     "kmeans": kmeans
# }

# output_pickle_file_minimal = 'scaler_kmeans.pkl'
# with open(output_pickle_file_minimal, 'wb') as pickle_file:
#     pickle.dump(objects_to_save_minimal, pickle_file)

# output_pickle_file_minimal
